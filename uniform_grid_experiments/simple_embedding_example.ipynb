# %%
from helpers import run, run_mult, Datasets, plot_points, plot_points_separate, plt

data_home = "../datasets"
log_path = "temp/poincaregpu/"

only_animate = False
seed = 42
perplexity = 15
logging = False


# RUNNING MNIST DATASET TEST
num_points = 10000
grid_n = 100

dataset = Datasets.MNIST
p, r, t = run(num_points, False, True, grid_n, seed, logging, log_path, dataset, perplexity, data_home)

plt.figure()

plot_points_separate([p], None, "MNIST Dataset Accuracy", "Precision", "Recall", [r])
# Out:
# Please note that `empty_sequence` uses the KL divergence with Barnes-Hut approximation (angle=0.5) by default.
# Loading Datasets.MNIST from ../datasets
# Loading data
# Data loading: 0.0 seconds
# Please note that `empty_sequence` uses the KL divergence with Barnes-Hut approximation (angle=0.5) by default.
# [HyperbolicTSNE] Received iterable as input. It should have len=2 and contain (D=None, V=None)
# [hd_mat] Warning: There is nothing to do with given parameters. Returning given D and V
# Gradient Descent:   0%|          | 0/250 [00:00<?, ?it/s]c:\Users\Milan\miniconda3\envs\htsne\lib\site-packages\hyperbolicTSNE\cost_functions_.py:329: UserWarning: The CUDA compiler succeeded, but said the following:
# kernel.cu
#
#   error = gradient(
# Gradient Descent error: 105.12696 grad_norm: 7.14854e-01: 100%|██████████| 250/250 [00:27<00:00,  9.05it/s]
# Gradient Descent error: 4.65532 grad_norm: 8.18474e-01:  41%|████      | 309/750 [00:20<00:29, 14.96it/s]
# 4
# [UGrid, d=Datasets.MNIST, n=10000, grid_n=100, seed=42] Execution time: 48.32062125205994 seconds
# Precision: [0.5534, 0.53415, 0.5181333333333334, 0.50155, 0.48622, 0.4728333333333334, 0.4616714285714285, 0.4503625, 0.44047777777777775, 0.4303700000000001, 0.4212272727272726, 0.4130666666666666, 0.40536923076923087, 0.3976357142857143, 0.39053333333333334, 0.3837125, 0.37783529411764705, 0.3721055555555555, 0.36643157894736844, 0.360875, 0.3550904761904761, 0.34969090909090905, 0.3446652173913043, 0.3396833333333333, 0.33492000000000005, 0.3301884615384616, 0.32555555555555554, 0.32142500000000007, 0.31687241379310344, 0.3124833333333333], recall: [0.018446666666666667, 0.03561, 0.05181333333333332, 0.06687333333333334, 0.08103666666666666, 0.09456666666666666, 0.10772333333333334, 0.12009666666666667, 0.13214333333333336, 0.1434566666666667, 0.15445000000000003, 0.1652266666666667, 0.17566, 0.18556333333333333, 0.19526666666666667, 0.20464666666666667, 0.2141066666666667, 0.2232633333333333, 0.23207333333333335, 0.24058333333333334, 0.24856333333333336, 0.25644, 0.26424333333333333, 0.27174666666666664, 0.2791, 0.2861633333333334, 0.293, 0.2999966666666667, 0.30630999999999997, 0.3124833333333333]
# c:\Git\hyperbolic-tsne\uniform_grid_experiments\helpers.py:194: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
