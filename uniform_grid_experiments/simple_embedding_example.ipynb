# %%
from helpers import run, run_mult, Datasets, plot_points, plot_points_separate, plt

data_home = "../datasets"
log_path = "temp/poincaregpu/"

only_animate = False
seed = 42
perplexity = 15
logging = False


# RUNNING MNIST DATASET TEST
num_points = 10000
grid_n = 100

dataset = Datasets.MNIST
p, r, t = run(num_points, False, True, grid_n, seed, logging, log_path, dataset, perplexity, data_home)

plt.figure()

plot_points_separate([p], None, "MNIST Dataset Accuracy", "Precision", "Recall", [r])
# Out:
# Loading Datasets.MNIST from ../datasets
# Loading data
# Data loading: 0.0 seconds
# Please note that `empty_sequence` uses the KL divergence with Barnes-Hut approximation (angle=0.5) by default.
# [HyperbolicTSNE] Received iterable as input. It should have len=2 and contain (D=None, V=None)
# [hd_mat] Warning: There is nothing to do with given parameters. Returning given D and V
# Gradient Descent error: 77.98497 grad_norm: 2.18108e+00: 100%|██████████| 250/250 [00:07<00:00, 32.31it/s]
# Gradient Descent error: 2.39723 grad_norm: 7.31546e-01:  77%|███████▋  | 579/750 [00:10<00:03, 53.66it/s]
# 4
# [UGrid, d=Datasets.MNIST, n=1000, grid_n=100, seed=42] Execution time: 18.53900122642517 seconds
# Precision: [0.881, 0.8575, 0.8356666666666667, 0.817, 0.798, 0.7786666666666667, 0.7627142857142857, 0.744125, 0.7254444444444443, 0.7065, 0.6902727272727273, 0.6703333333333333, 0.6537692307692309, 0.6370714285714285, 0.6237999999999999, 0.6099375, 0.5954705882352942, 0.5812777777777778, 0.569, 0.5551000000000001, 0.5460952380952381, 0.5365, 0.527695652173913, 0.5181666666666667, 0.5089600000000001, 0.49903846153846154, 0.48892592592592593, 0.47960714285714284, 0.4713103448275862, 0.46196666666666664], recall: [0.029366666666666662, 0.05716666666666666, 0.08356666666666668, 0.10893333333333334, 0.13300000000000003, 0.15573333333333333, 0.1779666666666667, 0.19843333333333335, 0.21763333333333332, 0.2355, 0.2531, 0.26813333333333333, 0.2833, 0.2973, 0.31189999999999996, 0.3253, 0.33743333333333336, 0.34876666666666667, 0.36036666666666667, 0.3700666666666666, 0.38226666666666664, 0.3934333333333333, 0.40456666666666663, 0.4145333333333333, 0.4241333333333333, 0.4325, 0.4400333333333333, 0.4476333333333333, 0.4556, 0.46196666666666664]
# c:\Git\hyperbolic-tsne\uniform_grid_experiments\helpers.py:194: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
